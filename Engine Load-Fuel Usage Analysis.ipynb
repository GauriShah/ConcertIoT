# %% [markdown]
# # Engine Load versus Fuel Usage Analysis for Concert IoT Data

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import math

from bokeh.charts import Histogram, show
from bokeh.plotting import output_notebook
output_notebook()

from bokeh.layouts import column
from bokeh.plotting import figure
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="df912d82-dd86-407f-8af8-13f9a7b185dc">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read in 3-month concert IoT data

# %%
df = pd.read_csv('concert_3month_data.csv', header=0)
df.head()
# Out:
#          DateTime  Coolant Temp      DateTime.1  Engine Load      DateTime.2  \
# 0  2/7/2017 12:26          19.0  2/7/2017 12:26          0.0  2/7/2017 12:26
# 1  2/7/2017 12:27          18.0  2/7/2017 12:27          0.0  2/7/2017 12:27
# 2  2/7/2017 12:28          18.0  2/7/2017 12:28          0.0  2/7/2017 12:28
# 3  2/7/2017 12:29          18.0  2/7/2017 12:29          0.0  2/7/2017 12:29
# 4  2/7/2017 12:30          18.0  2/7/2017 12:30          0.0  2/7/2017 12:30
#
#    Fuel Pressure      DateTime.3  Fuel Usage      DateTime.4  Oil Pressure  \
# 0            0.0  2/7/2017 12:26         0.0  2/7/2017 12:26           0.0
# 1            0.0  2/7/2017 12:27         0.0  2/7/2017 12:27           0.0
# 2            0.0  2/7/2017 12:28         0.0  2/7/2017 12:28           0.0
# 3            0.0  2/7/2017 12:29         0.0  2/7/2017 12:29           0.0
# 4            0.0  2/7/2017 12:30         0.0  2/7/2017 12:30           0.0
#
#       ...         DateTime.10  Engine Speed     DateTime.11  Air Intake Temp  \
# 0     ...      2/7/2017 12:26           0.0  2/7/2017 12:26             17.0
# 1     ...      2/7/2017 12:27           0.0  2/7/2017 12:27             18.0
# 2     ...      2/7/2017 12:28           0.0  2/7/2017 12:28             18.0
# 3     ...      2/7/2017 12:29           0.0  2/7/2017 12:29             18.0
# 4     ...      2/7/2017 12:30           0.0  2/7/2017 12:30             18.0
#
#       DateTime.12  Total Fuel Used     DateTime.13  Engine Hours  \
# 0  2/7/2017 12:31          21492.0  2/7/2017 12:32        1057.0
# 1  2/7/2017 12:32          21492.0  2/7/2017 12:34        1057.0
# 2  2/7/2017 12:34          21492.0  2/7/2017 12:35        1057.0
# 3  2/7/2017 12:35          21492.0  2/7/2017 12:36        1057.0
# 4  2/7/2017 12:36          21492.0  2/7/2017 12:38        1057.0
#
#       DateTime.14  Last Error
# 0  2/7/2017 12:26       516.0
# 1  2/7/2017 12:44       516.0
# 2  2/7/2017 12:51       516.0
# 3  2/7/2017 13:51       516.0
# 4   2/8/2017 8:55       516.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Read in the Engine Load data and format the date and time

# %%
el_df = df[[2,3]].copy()
el_df['DateTime.1'] = pd.to_datetime(el_df['DateTime.1'])
el_df.columns = ['DateTime', 'EngineLoad']
el_df.head()
# Out:
#              DateTime  EngineLoad
# 0 2017-02-07 12:26:00         0.0
# 1 2017-02-07 12:27:00         0.0
# 2 2017-02-07 12:28:00         0.0
# 3 2017-02-07 12:29:00         0.0
# 4 2017-02-07 12:30:00         0.0

# %% [markdown]
# ### Read in the Fuel Usage data and format the date and time

# %%
fu_df = df[[6,7]].copy()
fu_df['DateTime.3'] = pd.to_datetime(fu_df['DateTime.3'])
fu_df.columns = ['DateTime', 'FuelUsage']
fu_df.head()
# Out:
#              DateTime  FuelUsage
# 0 2017-02-07 12:26:00        0.0
# 1 2017-02-07 12:27:00        0.0
# 2 2017-02-07 12:28:00        0.0
# 3 2017-02-07 12:29:00        0.0
# 4 2017-02-07 12:30:00        0.0

# %% [markdown]
# ### Histogram of Engine Load Values

# %%
el_df.dropna(axis=0, inplace=True)
p = Histogram(el_df, values='EngineLoad', title= "Histogram of Engine Load Values", color='lightgreen')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ea3e3653-72be-4b8e-b3bf-ac6dc322a23a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ea3e3653-72be-4b8e-b3bf-ac6dc322a23a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ea3e3653-72be-4b8e-b3bf-ac6dc322a23a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ea3e3653-72be-4b8e-b3bf-ac6dc322a23a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e24154c2-37ea-4391-a3c9-fc2fe44cf8ae":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(81.290323, 81.935484]"],"color":["lightgreen"],"fill_alpha":[0.8],"height":[0.0],"label":["(81.290323, 81.935484]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6451612903225907],"x":["81.6129035"],"y":[0.0]}},"id":"b088eddf-5de7-4669-b6a8-6c94d7b94ce0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(81.935484, 82.580645]"],"color":["lightgreen"],"fill_alpha":[0.8],"height":[0.0],"label":["(81.935484, 82.580645]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6451612903225765],"x":["82.2580645"],"y":[0.0]}},"id":"93182f67-b540-434b-907d-4d265ae0465c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1c2b528-fff7-49b4-9068-f07b47fedf56","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(86.451613, 87.096774]"],"color":["lightgreen"],"fill_alpha":[0.8],"height":[0.0],"label":["(86.451613, 87.096774]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6451612903225765],"x":["86.7741935"],"y":[0.0]}},"id":"4d556b38-aef6-4d4d-a211-99bc76f71d97","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b088eddf-5de7-4669-b6a8-6c94d7b94ce0","type":"ColumnDataSource"},"glyph":{"id":"a1c2b528-fff7-49b4-9068-f07b47fedf56","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"50481595-9d73-4cd4-9b1c-1dc1c54891fb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(82.580645, 83.225806]"],"color":["lightgreen"],"fill_alpha":[0.8],"height":[0.0],"label":["(82.580645, 83.225806]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6451612903225765],"x":["82.9032255"],"y":[0.0]}},"id":"b8628f7a-4523-4c67-bd16-220e3d2c4cc6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae46ea84-6d0a-4f7c-ab67-4ee94c7c295a","type":"Rect"},{"attributes":{"data_source":{"id":"c2ce58ca-b2eb-4ad9-b675-24a5583332dd","type":"ColumnDataSource"},"glyph":{"id":"9881dc1a-d6b2-4da2-b263-d69e1bd5e2aa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6f039683-4326-45a3-ba85-49e665daacfd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"93182f67-b540-434b-907d-4d265ae0465c","type":"ColumnDataSource"},"glyph":{"id":"ae46ea84-6d0a-4f7c-ab67-4ee94c7c295a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6701ce78-0f49-4241-923a-d22b45ce90d4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(83.225806, 83.870968]"],"color":["lightgreen"],"fill_alpha":[0.8],"height":[0.0],"label":["(83.225806, 83.870968]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6451612903225907],"x":["83.548387"],"y":[0.0]}},"id":"981db67d-0327-48d8-a8bb-05b28ddc81d4","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width" ...

# %% [markdown]
# ### Histogram of Fuel Usage Values

# %%
fu_df.dropna(axis=0, inplace=True)
p = Histogram(fu_df, values='FuelUsage', title= "Histogram of Fuel Usage Values", color='dodgerblue')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c8536722-6363-4a3a-8d12-a2cd90ab023e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c8536722-6363-4a3a-8d12-a2cd90ab023e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c8536722-6363-4a3a-8d12-a2cd90ab023e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c8536722-6363-4a3a-8d12-a2cd90ab023e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fe66a023-5722-425e-b0bd-3decfa859ca8":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(40.631250, 41.158929]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[7.0],"label":["(40.631250, 41.158929]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285737],"x":["40.8950895"],"y":[3.5]}},"id":"f9914675-bc8e-4dd2-a97d-b3e0437f90a0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(7.915179, 8.442857]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[40.0],"label":["(7.915179, 8.442857]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285719],"x":["8.179018"],"y":[20.0]}},"id":"fd440e83-9036-46a0-b162-cfe8622d4b7b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(40.103571, 40.631250]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[10.0],"label":["(40.103571, 40.631250]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285737],"x":["40.367410500000005"],"y":[5.0]}},"id":"9da7e06e-fba8-4255-ae58-44d7b31f54d0","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1675.3000000000002},"id":"21092182-7abf-49be-a2ac-ccfe7c4249b3","type":"Range1d"},{"attributes":{"data_source":{"id":"fd440e83-9036-46a0-b162-cfe8622d4b7b","type":"ColumnDataSource"},"glyph":{"id":"67482665-ca32-4f83-9d7e-23fa48ccbde0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9a13d1db-6ebb-41c2-9033-ae6266d7b8fb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7992ed3-c786-4d66-b689-2b03bc7f5bb5","type":"Rect"},{"attributes":{"data_source":{"id":"9da7e06e-fba8-4255-ae58-44d7b31f54d0","type":"ColumnDataSource"},"glyph":{"id":"b7992ed3-c786-4d66-b689-2b03bc7f5bb5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"868b4f68-965d-4375-b00d-ad0b9d43a49c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(9.498214, 10.025893]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[26.0],"label":["(9.498214, 10.025893]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285701],"x":["9.7620535"],"y":[13.0]}},"id":"06436924-f223-430a-a0b5-1a6e2820a0f8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(41.158929, 41.686607]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[8.0],"label":["(41.158929, 41.686607]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285666],"x":["41.422768000000005"],"y":[4.0]}},"id":"e251ee3c-86e6-4eb4-925b-4bd40c4b61ae","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(10.025893, 10.553571]"],"color":["dodgerblue"],"fill_alpha":[0.8],"height":[33.0],"label":["(10.025893, 10.553571]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5276785714285719],"x":["10.289732"],"y":[16.5]}},"id":"cd6c15cf-ce13-470a-9450-448396f2b405","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"26c93adc-a0ff-4e95-8027-925a4b0fb05f","type":"ColumnDataSource"},"glyph":{"id":"cab59875-0524-4639-a3e6-e3317088a77b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null, ...

# %% [markdown]
# ### Merge the Engine Load and Fuel Usage values for matching timestamps

# %%
merged_df = pd.merge(el_df, fu_df, on='DateTime', how='inner')
merged_df.head()
# Out:
#              DateTime  EngineLoad  FuelUsage
# 0 2017-02-07 12:26:00         0.0        0.0
# 1 2017-02-07 12:27:00         0.0        0.0
# 2 2017-02-07 12:28:00         0.0        0.0
# 3 2017-02-07 12:29:00         0.0        0.0
# 4 2017-02-07 12:30:00         0.0        0.0

# %% [markdown]
# ### Round the Fuel Usage values into buckets of 10 and drop all 0 values

# %%
merged_df['FuelUsageRounded'] = merged_df['FuelUsage'].apply(lambda x: int(math.ceil(x / 10.0)) * 10)

# %%
def drop_all_zeroes(target_df, key1, key2):
    mask = (target_df[key1] != 0) & (target_df[key2] != 0)
    return mask

merged_df = merged_df.loc[drop_all_zeroes(merged_df, 'EngineLoad', 'FuelUsage')]
merged_df.head()
# print(merged_df.count)
# Out:
#               DateTime  EngineLoad  FuelUsage  FuelUsageRounded
# 6  2017-02-07 12:35:00        11.0       5.55                10
# 12 2017-02-07 12:45:00        19.0       7.45                10
# 18 2017-02-07 13:51:00        15.0       5.80                10
# 19 2017-02-07 14:19:00        11.0       5.45                10
# 20 2017-02-07 14:20:00        12.0       4.50                10

# %% [markdown]
# ### Histogram of Engine Load Values for different values of Fuel Usage

# %%
p1 = Histogram(merged_df, values='EngineLoad', 
               title= "Histogram of Engine Load Values for different Fuel Usage", 
               color='FuelUsageRounded', 
               palette=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
                        '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
p1.legend.location='top_right'
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3b0cb1da-2c95-4942-8c78-67b55c405f8c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3b0cb1da-2c95-4942-8c78-67b55c405f8c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3b0cb1da-2c95-4942-8c78-67b55c405f8c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3b0cb1da-2c95-4942-8c78-67b55c405f8c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"903b4cb9-f9c7-43bd-989f-fbd339c2f01a":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[18.000000, 19.261538]"],"color":["#d62728"],"fill_alpha":[0.6],"height":[1.0],"label":["[18.000000, 19.261538]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2615384615384606],"x":["18.630769"],"y":[0.5]}},"id":"bb7f3393-c6be-4e94-9485-b2940b065f55","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e3463fc1-ab3d-4148-ab4c-2a452bdf6289","type":"ColumnDataSource"},"glyph":{"id":"53b5f61b-57bb-498d-94f9-d941b2235ab8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7d6eb51b-d4d3-48cf-a1d4-88e1bc08cb55","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"65d83efa-ad73-4421-8e3d-ecdda043128d","type":"Rect"},{"attributes":{"data_source":{"id":"bb7f3393-c6be-4e94-9485-b2940b065f55","type":"ColumnDataSource"},"glyph":{"id":"65d83efa-ad73-4421-8e3d-ecdda043128d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"52029cc9-7864-40a0-b667-e0e90c9958a6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(19.261538, 20.523077]"],"color":["#d62728"],"fill_alpha":[0.6],"height":[0.0],"label":["(19.261538, 20.523077]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2615384615384606],"x":["19.8923075"],"y":[0.0]}},"id":"e3463fc1-ab3d-4148-ab4c-2a452bdf6289","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"53b5f61b-57bb-498d-94f9-d941b2235ab8","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"461af563-5bd8-4a4b-8415-23e25bdc6f9f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(62.529412, 63.070588]"],"color":["#ff7f0e"],"fill_alpha":[0.6],"height":[1.0],"label":["(62.529412, 63.070588]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5411764705882334],"x":["62.8"],"y":[0.5]}},"id":"a1789248-6afe-46e7-b0a6-8ab003734502","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(60.905882, 61.447059]"],"color":["#ff7f0e"],"fill_alpha":[0.6],"height":[0.0],"label":["(60.905882, 61.447059]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.5411764705882405],"x":["61.1764705"],"y":[0.0]}},"id":"541834bb-5dd1-49d7-9055-6db8df32839a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"541834bb-5dd1-49d7-9055-6db8df32839a","type":"ColumnDataSource"},"glyph":{"id":"0989cc6d-9023-43be-b48a-31d31bde436c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"acbe0fef-65ba-4a27-b992-9d7860668c4d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c627df03-e172-48c2-89c4-29a9a4235d10","type":"ColumnDataSource"},"glyph":{"id":"98d2a8ca-d445-4358-ac53-c7429ece144c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"17c78116-f2ed-45f6-91b2-3bf5ffb01ede","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_na ...

# %% [markdown]
# ### Linear Regression model between Engine Load and Fuel Usage

# %%
from sklearn import linear_model
import numpy as np

X = np.matrix(merged_df.head(1000)['EngineLoad'].values).T
y = np.matrix(merged_df.head(1000)['FuelUsage'].values).T
print(X.shape, y.shape)

regr = linear_model.LinearRegression()
regr.fit(X, y)
        
plt.scatter(X, y, color='blue')
plt.plot(X, regr.predict(X), color='red', linewidth=3)

plt.show()
# Out:
# (1000, 1) (1000, 1)

# %%
from scipy import stats

X = merged_df.head(1000)['EngineLoad']
y = merged_df.head(1000)['FuelUsage']

slope, intercept, i, j, k = stats.linregress(X, y)

line = slope*X + intercept
plt.plot(X, line, '-r', X, y, 'o', linewidth=3)
plt.xlabel('Engine Load')
plt.ylabel('Fuel Usage')
plt.show()

# %% [markdown]
# ### Polynomial (degree 2 and 3) Regression model between Engine Load and Fuel Usage

# %%
from numpy import *

z2 = polyfit(X.values, y, 2) 
p2 = poly1d(z2) # construct the polynomial 
print(poly1d(z2))

z3 = polyfit(X.values, y, 3)
p3 = poly1d(z3)
print(poly1d(z3))

xx = linspace(0, 100, 100)
plt.plot(X, y, 'o', xx, p2(xx),'-g', xx, p3(xx),'-r', linewidth=3)
plt.legend(['data to fit', '2nd degree poly', '3rd degree poly'])
plt.axis([0,100,0,100])
plt.xlabel('Engine Load')
plt.ylabel('Fuel Usage')
plt.show()
# Out:
#           2
# -0.01412 x + 1.49 x - 10.05
#             3            2
# -4.508e-05 x - 0.008841 x + 1.32 x - 8.536

# %% [markdown]
# ## Train a neural network to learn the Engine Load-Fuel Usage correlation

# %%
import tensorflow as tf

# %%
x = tf.placeholder(tf.float32, [None, 1])
W = tf.Variable(tf.zeros([1, 25]))
b = tf.Variable(tf.zeros([25]))
y = tf.nn.softmax(tf.matmul(x, W) + b)
y_ = tf.placeholder(tf.float32, [None, 1])
mean_square_error = tf.reduce_mean(tf.squared_difference(y_, y))
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(mean_square_error)
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()
i = 0
for _ in range(120):
    batch_xs = np.matrix(merged_df.iloc[i:i+100]['EngineLoad'].values).T
    batch_ys = np.matrix(merged_df.iloc[i:i+100]['FuelUsage'].values).T
    i = i+100
    sess.run(train_step, feed_dict={x: batch_xs, y_: batch_ys})
